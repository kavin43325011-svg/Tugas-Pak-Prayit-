# %% [markdown]
# <a href="https://colab.research.google.com/github/kavin43325011-svg/Tugas-Pak-Prayit-/blob/main/pratikum_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PRATIKUM 9**

# %% [markdown]
# **PRAKTIKUM 1**

# %%
import math

angka = 16
hasil1 = math.sqrt(angka)
hasil2 = math.pow(2, 5)
print("Akar kuadrat dari", angka, "=", hasil1)
print("2 pangkat 5 =", hasil2)
# Out:
# Akar kuadrat dari 16 = 4.0
# 2 pangkat 5 = 32.0

# %% [markdown]
# **PRAKTIKUM 2**

# %%
from math import sqrt

angka = 25
hasil = sqrt(angka)
print("Akar kuadrat dari", angka, "=", hasil)
# Out:
# Akar kuadrat dari 25 = 5.0

# %% [markdown]
# **PRAKTIKUM 3**

# %%
import numpy as np

data = np.array([1, 2, 3])
print("Isi array =", data)
# Out:
# Isi array = [1 2 3]

# %% [markdown]
# **PRAKTIKUM 4**

# %%
import math
import random
import sys

hasil1 = math.sqrt(81)
hasil2 = random.randint(1, 10)
versi = sys.version

print("Akar kuadrat 81 =", hasil1)
print("Angka acak 1–10 =", hasil2)
print("Versi Python =", versi)
# Out:
# Akar kuadrat 81 = 9.0
# Angka acak 1–10 = 9
# Versi Python = 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# **PRAKTIKUM 5**

# %%
# %%writefile modulku.py

def halo(nama):
  print(f"Halo, {nama}! Selamat belajar Python di Polines.")
# Out:
# Overwriting modulku.py

# %%
import modulku

modulku.halo("Mahasiswa Polines")
# Out:
# Halo, Mahasiswa Polines! Selamat belajar Python di Polines.

# %% [markdown]
# **PRAKTIKUM 6**

# %%
# !pip install requests

# %% [markdown]
# # **PENUGASAN**

# %% [markdown]
# **TUGAS 1**

# %%
import math

def luas_lingkaran(r):
    return math.pi * (r ** 2)

print("Luas lingkaran jari-jari 7 =", luas_lingkaran(7))
print("Luas lingkaran jari-jari 10 =", luas_lingkaran(10))
# Out:
# Luas lingkaran jari-jari 7 = 153.93804002589985
# Luas lingkaran jari-jari 10 = 314.1592653589793

# %% [markdown]
# **TUGAS 2**

# %%
import random

angka_acak = [random.randint(1, 100) for _ in range(5)]
print("Lima angka acak antara 1–100:", angka_acak)
# Out:
# Lima angka acak antara 1–100: [96, 34, 89, 96, 25]

# %% [markdown]
# **TUGAS 3**

# %%
import sys

print("Informasi sistem:")
print("Platform :", sys.platform)
print("Versi Python :", sys.version)
# Out:
# Informasi sistem:
# Platform : linux
# Versi Python : 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# **TUGAS 4**

# %%
# %%writefile konversi.py
def c_to_f(angka):
  f = angka * 1.8 + 32
  print(f"Konversi dari {angka} Celcius ke Fahrenheit adalah: °{f}")

def f_to_c(angka):
  c = (angka - 32 ) / 1.8
  print(f"Konversi dari {angka} Fahrenheit ke Celcius adalah: °{c}")
# Out:
# Writing konversi.py

# %%
import konversi

print("----- Konversi -----")
print("1. Celcius ke Fahrenheit")
print("2. Fahrenheit ke Celcius")
print("--------------------")
print()
pilih = int(input("Masukkan angka: "))


if pilih == 1:
  angka =int(input("Masukkan angka yang ingin anda konversi menjadi Fahrenheit: "))
  konversi.c_to_f(angka)
else:
  angka =int(input("Masukkan angka yang ingin anda konversi menjadi Celcius: "))
  konversi.f_to_c(angka)
# Out:
# ----- Konversi -----
# 1. Celcius ke Fahrenheit
# 2. Fahrenheit ke Celcius
# --------------------
#
# Masukkan angka: 1
# Masukkan angka yang ingin anda konversi menjadi Fahrenheit: 30
# Konversi dari 30 Celcius ke Fahrenheit adalah: °86.0

# %% [markdown]
# **TUGAS 5**

# %%
import pandas as pd

data = {
    "NIM": ["43325011", "43325012", "43325013"],
    "Nama": ["joko", "bowo", "harto"],
    "Prodi": ["Informatika", "Sistem Informasi", "Teknik Komputer"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#         NIM   Nama             Prodi
# 0  43325011   joko       Informatika
# 1  43325012   bowo  Sistem Informasi
# 2  43325013  harto   Teknik Komputer

# %% [markdown]
# **TUGAS 6**

# %%
import random
def tampilkan_ringkasan(jumlah_soal, skor):
    print("\n===== RINGKASAN SKOR =====")
    print("Jumlah Soal :", jumlah_soal)
    print("Jawaban Benar :", skor)
    print("Nilai Akhir :", (skor / jumlah_soal) * 100, "%")
    print("===========================")

# Program utama
print("=== KUIS PENJUMLAHAN SEDERHANA ===")

jumlah_soal = 5
skor = 0

for i in range(1, jumlah_soal + 1):
    a = random.randint(1, 10)
    b = random.randint(1, 10)
    print(f"Soal {i}: {a} + {b} = ", end="")
    jawaban = int(input())

    if jawaban == a + b:
        print("Benar!\n")
        skor += 1
    else:
        print(f"Salah! Jawaban yang benar adalah {a + b}\n")

# Panggil fungsi laporan
tampilkan_ringkasan(jumlah_soal, skor)
# Out:
# === KUIS PENJUMLAHAN SEDERHANA ===
# Soal 1: 2 + 7 = 9
# Benar!
#
# Soal 2: 6 + 8 = 14
# Benar!
#
# Soal 3: 1 + 7 = 10
# Salah! Jawaban yang benar adalah 8
#
# Soal 4: 6 + 10 =
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1858945471.py in <cell line: 0>()
#      17     b = random.randint(1, 10)
#      18     print(f"Soal {i}: {a} + {b} = ", end="")
# ---> 19     jawaban = int(input())
#      20
#      21     if jawaban == a + b:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
